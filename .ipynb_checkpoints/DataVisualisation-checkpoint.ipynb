# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
stock_data = pd.read_csv('D:\Google Drive\KRIS UNI Year 3\FYP\Agent-Based-Simulation-in-blockchain-economics\OutputData/2019-20_BTC-USD.csv')
stock_data.head(5)
# Out:
#          Date         High          Low         Open        Close      Volume  \
# 0  2019-01-01  3850.913818  3707.231201  3746.713379  3843.520020  4324200990
# 1  2019-01-02  3947.981201  3817.409424  3849.216309  3943.409424  5244856835
# 2  2019-01-03  3935.685059  3826.222900  3931.048584  3836.741211  4530215218
# 3  2019-01-04  3865.934570  3783.853760  3832.040039  3857.717529  4847965467
# 4  2019-01-05  3904.903076  3836.900146  3851.973877  3845.194580  5137609823
#
#      Adj Close
# 0  3843.520020
# 1  3943.409424
# 2  3836.741211
# 3  3857.717529
# 4  3845.194580

# %%
stock_data[["Date", "Adj Close"]].plot(x="Date", kind="line", figsize=(15,5))

# %%
sentiment_result = pd.read_csv('D:\Google Drive\KRIS UNI Year 3\FYP\Agent-Based-Simulation-in-blockchain-economics\ProcessedData\SentimentAnalysisResults.csv')
sentiment_result.head(5)
# Out:
#      TWITTER ID  CREATED AT  \
# 0  1.210000e+18  31/12/2019
# 1  1.210000e+18  31/12/2019
# 2  1.210000e+18  31/12/2019
# 3  1.210000e+18  31/12/2019
# 4  1.210000e+18  31/12/2019
#
#                                                 TEXT Multinomial Naive Bayes  \
# 0  b'@ZubyMusic @DigitalLawrence From comp sci st...                Negative
# 1  b'@funnybrinjal As stated previously in anothe...                Positive
# 2  b'With 9,065,480 PART supply and inflation dec...                Negative
# 3  b"Cryptohopper wishes everyone a happy new yea...                Positive
# 4  b'Ecommerce SEO Guide: 7 Ecommerce Optimizatio...                Positive
#
#   Bernoulli Naive Bayes Logistic Regression Linear Support Vector  \
# 0              Negative            Positive              Positive
# 1              Positive            Positive              Positive
# 2              Negative            Positive              Positive
# ...

# %%
stock_prediction = pd.read_csv('D:\Google Drive\KRIS UNI Year 3\FYP\Agent-Based-Simulation-in-blockchain-economics\ProcessedData\StockPrediction.csv')
stock_prediction.tail(5)
# Out:
#            Date    Adj Close  Prediction  LR Prediction  SVR Prediction
# 392  28/01/2020  9358.589844         NaN    9221.904428     8173.563004
# 393  29/01/2020  9316.629883         NaN    9190.710147     8173.164012
# 394  30/01/2020  9508.993164         NaN    9333.718722     8174.831016
# 395  31/01/2020  9350.529297         NaN    9215.911978     8173.487888
# 396  01/02/2020  9392.875000         NaN    9247.393031     8173.874373

# %%
stock_prediction[["Date", "Adj Close", "Prediction", "LR Prediction", "SVR Prediction"]].plot(x="Date", kind="line", figsize=(15,5), grid = True)

# %%
naive_bayes_count = pd.read_csv('D:\Google Drive\KRIS UNI Year 3\FYP\Agent-Based-Simulation-in-blockchain-economics\ProcessedData\naive_bayes_count.csv')
naive_bayes_count.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-696f31f8fac2> in <module>
# ----> 1 naive_bayes_count = pd.read_csv('D:\Google Drive\KRIS UNI Year 3\FYP\Agent-Based-Simulation-in-blockchain-economics\ProcessedData\naive_bayes_count.csv')
#       2 naive_bayes_count.head(5)
#
# ...
